# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from tqdm import tqdm

pi = np.pi
sns.set_theme(palette='muted',font_scale=1.3)
plt.rcParams.update({'font.size': 20})

# %%
df = pd.read_csv('./data/train_set.csv', index_col=0)
cols = df.columns
idxs = df.index

# %%
cols = df.columns
col_genes = []
for i in range(len(cols)):
    col = cols[i]
    if '+' in col:
        split = col.split('+')
        col_genes.append(split[0])
        col_genes.append(split[1])
    else:
        col_genes.append(col)

# %%
singles = [x for x in cols if 'ctrl' in x]
singles.sort()
singles
# Out:
# ['ctrl',
#  'ctrl.1',
#  'ctrl.10',
#  'ctrl.11',
#  'ctrl.12',
#  'ctrl.13',
#  'ctrl.14',
#  'ctrl.15',
#  'ctrl.16',
#  'ctrl.17',
#  'ctrl.18',
#  'ctrl.19',
#  'ctrl.2',
#  'ctrl.20',
#  'ctrl.21',
#  'ctrl.22',
#  'ctrl.23',
#  'ctrl.24',
#  'ctrl.25',
#  'ctrl.26',
#  'ctrl.27',
#  'ctrl.28',
#  'ctrl.29',
#  'ctrl.3',
#  'ctrl.30',
#  'ctrl.31',
#  'ctrl.32',
#  'ctrl.33',
#  'ctrl.34',
#  'ctrl.35',
#  'ctrl.36',
#  'ctrl.37',
#  'ctrl.38',
#  'ctrl.39',
#  'ctrl.4',
#  'ctrl.5',
#  'ctrl.6',
#  'ctrl.7',
#  'ctrl.8',
#  'ctrl.9',
#  'g0013+ctrl',
#  'g0013+ctrl.1',
#  'g0013+ctrl.10',
#  'g0013+ctrl.11',
#  'g0013+ctrl.12',
#  'g0013+ctrl.13',
#  'g0013+ctrl.14',
#  'g0013+ctrl.15',
#  'g0013+ctrl.16',
#  'g0013+ctrl.17',
#  'g0013+ctrl.18',
#  'g0013+ctrl.19',
#  'g0013+ctrl.2',
#  'g0013+ctrl.20',
#  'g0013+ctrl.21',
#  'g0013+ctrl.22',
#  'g0013+ctrl.23',
#  'g0013+ctrl.24',
#  'g0013+ctrl.25',
#  'g0013+ctrl.26',
#  'g0013+ctrl.27',
#  'g0013+ctrl.28',
#  'g0013+ctrl.29',
#  'g0013+ctrl.3',
#  'g0013+ctrl.30',
#  'g0013+ctrl.31',
#  'g0013+ctrl.32',
#  'g0013+ctrl.33',
#  'g0013+ctrl.34',
#  'g0013+ctrl.35',
#  'g0013+ctrl.36',
#  'g0013+ctrl.37',
#  'g0013+ctrl.38',
#  'g0013+ctrl.39',
#  'g0013+ctrl.4',
#  'g0013+ctrl.5',
#  'g0013+ctrl.6',
#  'g0013+ctrl.7',
#  'g0013+ctrl.8',
#  'g0013+ctrl.9',
#  'g0016+ctrl',
#  'g0016+ctrl.1',
#  'g0016+ctrl.10',
#  'g0016+ctrl.11',
#  'g0016+ctrl.12',
#  'g0016+ctrl.13',
#  'g0016+ctrl.14',
#  'g0016+ctrl.15',
#  'g0016+ctrl.16',
#  'g0016+ctrl.17',
#  'g0016+ctrl.18',
#  'g0016+ctrl.19',
#  'g0016+ctrl.2',
#  'g0016+ctrl.20',
#  'g0016+ctrl.21',
#  'g0016+ctrl.22',
#  'g0016+ctrl.23',
#  'g0016+ctrl.24',
#  'g0016+ctrl.25',
#  'g0016+ctrl.26',
#  'g0016+ctrl.27',
#  'g0016+ctrl.28',
#  'g0016+ctrl.29',
#  'g0016+ctrl.3',
#  'g0016+ctrl.30',
#  'g0016+ctrl.31',
#  'g0016+ctrl.32',
#  'g0016+ctrl.33',
#  'g0016+ctrl.34',
#  'g0016+ctrl.35',
#  'g0016+ctrl.36',
#  'g0016+ctrl.37',
#  'g0016+ctrl.38',
#  'g0016+ctrl.39',
#  'g0016+ctrl.4',
#  'g0016+ctrl.5',
#  'g0016+ctrl.6',
#  'g0016+ctrl.7',
#  'g0016+ctrl.8',
#  'g0016+ctrl.9',
#  'g0022+ctrl',
#  'g0022+ctrl.1',
#  'g0022+ctrl.10',
#  'g0022+ctrl.11',
#  'g0022+ctrl.12',
#  'g0022+ctrl.13',
#  'g0022+ctrl.14',
#  'g0022+ctrl.15',
#  'g0022+ctrl.16',
#  'g0022+ctrl.17',
#  'g0022+ctrl.18',
#  'g0022+ctrl.19',
#  'g0022+ctrl.2',
#  'g0022+ctrl.20',
#  'g0022+ctrl.21',
#  'g0022+ctrl.22',
#  'g0022+ctrl.23',
#  'g0022+ctrl.24',
#  'g0022+ctrl.25',
#  'g0022+ctrl.26',
#  'g0022+ctrl.27',
#  'g0022+ctrl.28',
#  'g0022+ctrl.29',
#  'g0022+ctrl.3',
#  'g0022+ctrl.30',
#  'g0022+ctrl.31',
#  'g0022+ctrl.32',
#  'g0022+ctrl.33',
#  'g0022+ctrl.34',
#  'g0022+ctrl.35',
#  'g0022+ctrl.36',
#  'g0022+ctrl.37',
#  'g0022+ctrl.38',
#  'g0022+ctrl.39',
#  'g0022+ctrl.4',
#  'g0022+ctrl.5',
#  'g0022+ctrl.6',
#  'g0022+ctrl.7',
#  'g0022+ctrl.8',
#  'g0022+ctrl.9',
#  'g0034+ctrl',
#  'g0034+ctrl.1',
#  'g0034+ctrl.10',
#  'g0034+ctrl.11',
#  'g0034+ctrl.12',
#  'g0034+ctrl.13',
#  'g0034+ctrl.14',
#  'g0034+ctrl.15',
#  'g0034+ctrl.16',
#  'g0034+ctrl.17',
#  'g0034+ctrl.18',
#  'g0034+ctrl.19',
#  'g0034+ctrl.2',
#  'g0034+ctrl.20',
#  'g0034+ctrl.21',
#  'g0034+ctrl.22',
#  'g0034+ctrl.23',
#  'g0034+ctrl.24',
#  'g0034+ctrl.25',
#  'g0034+ctrl.26',
#  'g0034+ctrl.27',
#  'g0034+ctrl.28',
#  'g0034+ctrl.29',
#  'g0034+ctrl.3',
#  'g0034+ctrl.30',
#  'g0034+ctrl.31',
#  'g0034+ctrl.32',
#  'g0034+ctrl.33',
#  'g0034+ctrl.34',
#  'g0034+ctrl.35',
#  'g0034+ctrl.36',
#  'g0034+ctrl.37',
#  'g0034+ctrl.38',
#  'g0034+ctrl.39',
#  'g0034+ctrl.4',
#  'g0034+ctrl.5',
#  'g0034+ctrl.6',
#  'g0034+ctrl.7',
#  'g0034+ctrl.8',
#  'g0034+ctrl.9',
#  'g0037+ctrl',
#  'g0037+ctrl.1',
#  'g0037+ctrl.10',
#  'g0037+ctrl.11',
#  'g0037+ctrl.12',
#  'g0037+ctrl.13',
#  'g0037+ctrl.14',
#  'g0037+ctrl.15',
#  'g0037+ctrl.16',
#  'g0037+ctrl.17',
#  'g0037+ctrl.18',
#  'g0037+ctrl.19',
#  'g0037+ctrl.2',
#  'g0037+ctrl.20',
#  'g0037+ctrl.21',
#  'g0037+ctrl.22',
#  'g0037+ctrl.23',
#  'g0037+ctrl.24',
#  'g0037+ctrl.25',
#  'g0037+ctrl.26',
#  'g0037+ctrl.27',
#  'g0037+ctrl.28',
#  'g0037+ctrl.29',
#  'g0037+ctrl.3',
#  'g0037+ctrl.30',
#  'g0037+ctrl.31',
#  'g0037+ctrl.32',
#  'g0037+ctrl.33',
#  'g0037+ctrl.34',
#  'g0037+ctrl.35',
#  'g0037+ctrl.36',
#  'g0037+ctrl.37',
#  'g0037+ctrl.38',
#  'g0037+ctrl.39',
#  'g0037+ctrl.4',
#  'g0037+ctrl.5',
#  'g0037+ctrl.6',
#  'g0037+ctrl.7',
#  'g0037+ctrl.8',
#  'g0037+ctrl.9',
#  'g0040+ctrl',
#  'g0040+ctrl.1',
#  'g0040+ctrl.10',
#  'g0040+ctrl.11',
#  'g0040+ctrl.12',
#  'g0040+ctrl.13',
#  'g0040+ctrl.14',
#  'g0040+ctrl.15',
#  'g0040+ctrl.16',
#  'g0040+ctrl.17',
#  'g0040+ctrl.18',
#  'g0040+ctrl.19',
#  'g0040+ctrl.2',
#  'g0040+ctrl.20',
#  'g0040+ctrl.21',
#  'g0040+ctrl.22',
#  'g0040+ctrl.23',
#  'g0040+ctrl.24',
#  'g0040+ctrl.25',
#  'g0040+ctrl.26',
#  'g0040+ctrl.27',
#  'g0040+ctrl.28',
#  'g0040+ctrl.29',
#  'g0040+ctrl.3',
#  'g0040+ctrl.30',
#  'g0040+ctrl.31',
#  'g0040+ctrl.32',
#  'g0040+ctrl.33',
#  'g0040+ctrl.34',
#  'g0040+ctrl.35',
#  'g0040+ctrl.36',
#  'g0040+ctrl.37',
#  'g0040+ctrl.38',
#  'g0040+ctrl.39',
#  'g0040+ctrl.4',
#  'g0040+ctrl.5',
#  'g0040+ctrl.6',
#  'g0040+ctrl.7',
#  'g0040+ctrl.8',
#  'g0040+ctrl.9',
#  'g0061+ctrl',
#  'g0061+ctrl.1',
#  'g0061+ctrl.10',
#  'g0061+ctrl.11',
#  'g0061+ctrl.12',
#  'g0061+ctrl.13',
#  'g0061+ctrl.14',
#  'g0061+ctrl.15',
#  'g0061+ctrl.16',
#  'g0061+ctrl.17',
#  'g0061+ctrl.18',
#  'g0061+ctrl.19',
#  'g0061+ctrl.2',
#  'g0061+ctrl.20',
#  'g0061+ctrl.21',
#  'g0061+ctrl.22',
#  'g0061+ctrl.23',
#  'g0061+ctrl.24',
#  'g0061+ctrl.25',
#  'g0061+ctrl.26',
#  'g0061+ctrl.27',
#  'g0061+ctrl.28',
#  'g0061+ctrl.29',
#  'g0061+ctrl.3',
#  'g0061+ctrl.30',
#  'g0061+ctrl.31',
#  'g0061+ctrl.32',
#  'g0061+ctrl.33',
#  'g0061+ctrl.34',
#  'g0061+ctrl.35',
#  'g0061+ctrl.36',
#  'g0061+ctrl.37',
#  'g0061+ctrl.38',
#  'g0061+ctrl.39',
#  'g0061+ctrl.4',
#  'g0061+ctrl.5',
#  'g0061+ctrl.6',
#  'g0061+ctrl.7',
#  'g0061+ctrl.8',
#  'g0061+ctrl.9',
#  'g0062+ctrl',
#  'g0062+ctrl.1',
#  'g0062+ctrl.10',
#  'g0062+ctrl.11',
#  'g0062+ctrl.12',
#  'g0062+ctrl.13',
#  'g0062+ctrl.14',
#  'g0062+ctrl.15',
#  'g0062+ctrl.16',
#  'g0062+ctrl.17',
#  'g0062+ctrl.18',
#  'g0062+ctrl.19',
#  'g0062+ctrl.2',
#  'g0062+ctrl.20',
#  'g0062+ctrl.21',
#  'g0062+ctrl.22',
#  'g0062+ctrl.23',
#  'g0062+ctrl.24',
#  'g0062+ctrl.25',
#  'g0062+ctrl.26',
#  'g0062+ctrl.27',
#  'g0062+ctrl.28',
#  'g0062+ctrl.29',
#  'g0062+ctrl.3',
#  'g0062+ctrl.30',
#  'g0062+ctrl.31',
#  'g0062+ctrl.32',
#  'g0062+ctrl.33',
#  'g0062+ctrl.34',
#  'g0062+ctrl.35',
#  'g0062+ctrl.36',
#  'g0062+ctrl.37',
#  'g0062+ctrl.38',
#  'g0062+ctrl.39',
#  'g0062+ctrl.4',
#  'g0062+ctrl.5',
#  'g0062+ctrl.6',
#  'g0062+ctrl.7',
#  'g0062+ctrl.8',
#  'g0062+ctrl.9',
#  'g0076+ctrl',
#  'g0076+ctrl.1',
#  'g0076+ctrl.10',
#  'g0076+ctrl.11',
#  'g0076+ctrl.12',
#  'g0076+ctrl.13',
#  'g0076+ctrl.14',
#  'g0076+ctrl.15',
#  'g0076+ctrl.16',
#  'g0076+ctrl.17',
#  'g0076+ctrl.18',
#  'g0076+ctrl.19',
#  'g0076+ctrl.2',
#  'g0076+ctrl.20',
#  'g0076+ctrl.21',
#  'g0076+ctrl.22',
#  'g0076+ctrl.23',
#  'g0076+ctrl.24',
#  'g0076+ctrl.25',
#  'g0076+ctrl.26',
#  'g0076+ctrl.27',
#  'g0076+ctrl.28',
#  'g0076+ctrl.29',
#  'g0076+ctrl.3',
#  'g0076+ctrl.30',
#  'g0076+ctrl.31',
#  'g0076+ctrl.32',
#  'g0076+ctrl.33',
#  'g0076+ctrl.34',
#  'g0076+ctrl.35',
#  'g0076+ctrl.36',
#  'g0076+ctrl.37',
#  'g0076+ctrl.38',
#  'g0076+ctrl.39',
#  'g0076+ctrl.4',
#  'g0076+ctrl.5',
#  'g0076+ctrl.6',
#  'g0076+ctrl.7',
#  'g0076+ctrl.8',
#  'g0076+ctrl.9',
#  'g0079+ctrl',
#  'g0079+ctrl.1',
#  'g0079+ctrl.10',
#  'g0079+ctrl.11',
#  'g0079+ctrl.12',
#  'g0079+ctrl.13',
#  'g0079+ctrl.14',
#  'g0079+ctrl.15',
#  'g0079+ctrl.16',
#  'g0079+ctrl.17',
#  'g0079+ctrl.18',
#  'g0079+ctrl.19',
#  'g0079+ctrl.2',
#  'g0079+ctrl.20',
#  'g0079+ctrl.21',
#  'g0079+ctrl.22',
#  'g0079+ctrl.23',
#  'g0079+ctrl.24',
#  'g0079+ctrl.25',
#  'g0079+ctrl.26',
#  'g0079+ctrl.27',
#  'g0079+ctrl.28',
#  'g0079+ctrl.29',
#  'g0079+ctrl.3',
#  'g0079+ctrl.30',
#  'g0079+ctrl.31',
#  'g0079+ctrl.32',
#  'g0079+ctrl.33',
#  'g0079+ctrl.34',
#  'g0079+ctrl.35',
#  'g0079+ctrl.36',
#  'g0079+ctrl.37',
#  'g0079+ctrl.38',
#  'g0079+ctrl.39',
#  'g0079+ctrl.4',
#  'g0079+ctrl.5',
#  'g0079+ctrl.6',
#  'g0079+ctrl.7',
#  'g0079+ctrl.8',
#  'g0079+ctrl.9',
#  'g0083+ctrl',
#  'g0083+ctrl.1',
#  'g0083+ctrl.10',
#  'g0083+ctrl.11',
#  'g0083+ctrl.12',
#  'g0083+ctrl.13',
#  'g0083+ctrl.14',
#  'g0083+ctrl.15',
#  'g0083+ctrl.16',
#  'g0083+ctrl.17',
#  'g0083+ctrl.18',
#  'g0083+ctrl.19',
#  'g0083+ctrl.2',
#  'g0083+ctrl.20',
#  'g0083+ctrl.21',
#  'g0083+ctrl.22',
#  'g0083+ctrl.23',
#  'g0083+ctrl.24',
#  'g0083+ctrl.25',
#  'g0083+ctrl.26',
#  'g0083+ctrl.27',
#  'g0083+ctrl.28',
#  'g0083+ctrl.29',
#  'g0083+ctrl.3',
#  'g0083+ctrl.30',
#  'g0083+ctrl.31',
#  'g0083+ctrl.32',
#  'g0083+ctrl.33',
#  'g0083+ctrl.34',
#  'g0083+ctrl.35',
#  'g0083+ctrl.36',
#  'g0083+ctrl.37',
#  'g0083+ctrl.38',
#  'g0083+ctrl.39',
#  'g0083+ctrl.4',
#  'g0083+ctrl.5',
#  'g0083+ctrl.6',
#  'g0083+ctrl.7',
#  'g0083+ctrl.8',
#  'g0083+ctrl.9',
#  'g0084+ctrl',
#  'g0084+ctrl.1',
#  'g0084+ctrl.10',
#  'g0084+ctrl.11',
#  'g0084+ctrl.12',
#  'g0084+ctrl.13',
#  'g0084+ctrl.14',
#  'g0084+ctrl.15',
#  'g0084+ctrl.16',
#  'g0084+ctrl.17',
#  'g0084+ctrl.18',
#  'g0084+ctrl.19',
#  'g0084+ctrl.2',
#  'g0084+ctrl.20',
#  'g0084+ctrl.21',
#  'g0084+ctrl.22',
#  'g0084+ctrl.23',
#  'g0084+ctrl.24',
#  'g0084+ctrl.25',
#  'g0084+ctrl.26',
#  'g0084+ctrl.27',
#  'g0084+ctrl.28',
#  'g0084+ctrl.29',
#  'g0084+ctrl.3',
#  'g0084+ctrl.30',
#  'g0084+ctrl.31',
#  'g0084+ctrl.32',
#  'g0084+ctrl.33',
#  'g0084+ctrl.34',
#  'g0084+ctrl.35',
#  'g0084+ctrl.36',
#  'g0084+ctrl.37',
#  'g0084+ctrl.38',
#  'g0084+ctrl.39',
#  'g0084+ctrl.4',
#  'g0084+ctrl.5',
#  'g0084+ctrl.6',
#  'g0084+ctrl.7',
#  'g0084+ctrl.8',
#  'g0084+ctrl.9',
#  'g0085+ctrl',
#  'g0085+ctrl.1',
#  'g0085+ctrl.10',
#  'g0085+ctrl.11',
#  'g0085+ctrl.12',
#  'g0085+ctrl.13',
#  'g0085+ctrl.14',
#  'g0085+ctrl.15',
#  'g0085+ctrl.16',
#  'g0085+ctrl.17',
#  'g0085+ctrl.18',
#  'g0085+ctrl.19',
#  'g0085+ctrl.2',
#  'g0085+ctrl.20',
#  'g0085+ctrl.21',
#  'g0085+ctrl.22',
#  'g0085+ctrl.23',
#  'g0085+ctrl.24',
#  'g0085+ctrl.25',
#  'g0085+ctrl.26',
#  'g0085+ctrl.27',
#  'g0085+ctrl.28',
#  'g0085+ctrl.29',
#  'g0085+ctrl.3',
#  'g0085+ctrl.30',
#  'g0085+ctrl.31',
#  'g0085+ctrl.32',
#  'g0085+ctrl.33',
#  'g0085+ctrl.34',
#  'g0085+ctrl.35',
#  'g0085+ctrl.36',
#  'g0085+ctrl.37',
#  'g0085+ctrl.38',
#  'g0085+ctrl.39',
#  'g0085+ctrl.4',
#  'g0085+ctrl.5',
#  'g0085+ctrl.6',
#  'g0085+ctrl.7',
#  'g0085+ctrl.8',
#  'g0085+ctrl.9',
#  'g0087+ctrl',
#  'g0087+ctrl.1',
#  'g0087+ctrl.10',
#  'g0087+ctrl.11',
#  'g0087+ctrl.12',
#  'g0087+ctrl.13',
#  'g0087+ctrl.14',
#  'g0087+ctrl.15',
#  'g0087+ctrl.16',
#  'g0087+ctrl.17',
#  'g0087+ctrl.18',
#  'g0087+ctrl.19',
#  'g0087+ctrl.2',
#  'g0087+ctrl.20',
#  'g0087+ctrl.21',
#  'g0087+ctrl.22',
#  'g0087+ctrl.23',
#  'g0087+ctrl.24',
#  'g0087+ctrl.25',
#  'g0087+ctrl.26',
#  'g0087+ctrl.27',
#  'g0087+ctrl.28',
#  'g0087+ctrl.29',
#  'g0087+ctrl.3',
#  'g0087+ctrl.30',
#  'g0087+ctrl.31',
#  'g0087+ctrl.32',
#  'g0087+ctrl.33',
#  'g0087+ctrl.34',
#  'g0087+ctrl.35',
#  'g0087+ctrl.36',
#  'g0087+ctrl.37',
#  'g0087+ctrl.38',
#  'g0087+ctrl.39',
#  'g0087+ctrl.4',
#  'g0087+ctrl.5',
#  'g0087+ctrl.6',
#  'g0087+ctrl.7',
#  'g0087+ctrl.8',
#  'g0087+ctrl.9',
#  'g0095+ctrl',
#  'g0095+ctrl.1',
#  'g0095+ctrl.10',
#  'g0095+ctrl.11',
#  'g0095+ctrl.12',
#  'g0095+ctrl.13',
#  'g0095+ctrl.14',
#  'g0095+ctrl.15',
#  'g0095+ctrl.16',
#  'g0095+ctrl.17',
#  'g0095+ctrl.18',
#  'g0095+ctrl.19',
#  'g0095+ctrl.2',
#  'g0095+ctrl.20',
#  'g0095+ctrl.21',
#  'g0095+ctrl.22',
#  'g0095+ctrl.23',
#  'g0095+ctrl.24',
#  'g0095+ctrl.25',
#  'g0095+ctrl.26',
#  'g0095+ctrl.27',
#  'g0095+ctrl.28',
#  'g0095+ctrl.29',
#  'g0095+ctrl.3',
#  'g0095+ctrl.30',
#  'g0095+ctrl.31',
#  'g0095+ctrl.32',
#  'g0095+ctrl.33',
#  'g0095+ctrl.34',
#  'g0095+ctrl.35',
#  'g0095+ctrl.36',
#  'g0095+ctrl.37',
#  'g0095+ctrl.38',
#  'g0095+ctrl.39',
#  'g0095+ctrl.4',
#  'g0095+ctrl.5',
#  'g0095+ctrl.6',
#  'g0095+ctrl.7',
#  'g0095+ctrl.8',
#  'g0095+ctrl.9',
#  'g0101+ctrl',
#  'g0101+ctrl.1',
#  'g0101+ctrl.10',
#  'g0101+ctrl.11',
#  'g0101+ctrl.12',
#  'g0101+ctrl.13',
#  'g0101+ctrl.14',
#  'g0101+ctrl.15',
#  'g0101+ctrl.16',
#  'g0101+ctrl.17',
#  'g0101+ctrl.18',
#  'g0101+ctrl.19',
#  'g0101+ctrl.2',
#  'g0101+ctrl.20',
#  'g0101+ctrl.21',
#  'g0101+ctrl.22',
#  'g0101+ctrl.23',
#  'g0101+ctrl.24',
#  'g0101+ctrl.25',
#  'g0101+ctrl.26',
#  'g0101+ctrl.27',
#  'g0101+ctrl.28',
#  'g0101+ctrl.29',
#  'g0101+ctrl.3',
#  'g0101+ctrl.30',
#  'g0101+ctrl.31',
#  'g0101+ctrl.32',
#  'g0101+ctrl.33',
#  'g0101+ctrl.34',
#  'g0101+ctrl.35',
#  'g0101+ctrl.36',
#  'g0101+ctrl.37',
#  'g0101+ctrl.38',
#  'g0101+ctrl.39',
#  'g0101+ctrl.4',
#  'g0101+ctrl.5',
#  'g0101+ctrl.6',
#  'g0101+ctrl.7',
#  'g0101+ctrl.8',
#  'g0101+ctrl.9',
#  'g0109+ctrl',
#  'g0109+ctrl.1',
#  'g0109+ctrl.10',
#  'g0109+ctrl.11',
#  'g0109+ctrl.12',
#  'g0109+ctrl.13',
#  'g0109+ctrl.14',
#  'g0109+ctrl.15',
#  'g0109+ctrl.16',
#  'g0109+ctrl.17',
#  'g0109+ctrl.18',
#  'g0109+ctrl.19',
#  'g0109+ctrl.2',
#  'g0109+ctrl.20',
#  'g0109+ctrl.21',
#  'g0109+ctrl.22',
#  'g0109+ctrl.23',
#  'g0109+ctrl.24',
#  'g0109+ctrl.25',
#  'g0109+ctrl.26',
#  'g0109+ctrl.27',
#  'g0109+ctrl.28',
#  'g0109+ctrl.29',
#  'g0109+ctrl.3',
#  'g0109+ctrl.30',
#  'g0109+ctrl.31',
#  'g0109+ctrl.32',
#  'g0109+ctrl.33',
#  'g0109+ctrl.34',
#  'g0109+ctrl.35',
#  'g0109+ctrl.36',
#  'g0109+ctrl.37',
#  'g0109+ctrl.38',
#  'g0109+ctrl.39',
#  'g0109+ctrl.4',
#  'g0109+ctrl.5',
#  'g0109+ctrl.6',
#  'g0109+ctrl.7',
#  'g0109+ctrl.8',
#  'g0109+ctrl.9',
#  'g0136+ctrl',
#  'g0136+ctrl.1',
#  'g0136+ctrl.10',
#  'g0136+ctrl.11',
#  'g0136+ctrl.12',
#  'g0136+ctrl.13',
#  'g0136+ctrl.14',
#  'g0136+ctrl.15',
#  'g0136+ctrl.16',
#  'g0136+ctrl.17',
#  'g0136+ctrl.18',
#  'g0136+ctrl.19',
#  'g0136+ctrl.2',
#  'g0136+ctrl.20',
#  'g0136+ctrl.21',
#  'g0136+ctrl.22',
#  'g0136+ctrl.23',
#  'g0136+ctrl.24',
#  'g0136+ctrl.25',
#  'g0136+ctrl.26',
#  'g0136+ctrl.27',
#  'g0136+ctrl.28',
#  'g0136+ctrl.29',
#  'g0136+ctrl.3',
#  'g0136+ctrl.30',
#  'g0136+ctrl.31',
#  'g0136+ctrl.32',
#  'g0136+ctrl.33',
#  'g0136+ctrl.34',
#  'g0136+ctrl.35',
#  'g0136+ctrl.36',
#  'g0136+ctrl.37',
#  'g0136+ctrl.38',
#  'g0136+ctrl.39',
#  'g0136+ctrl.4',
#  'g0136+ctrl.5',
#  'g0136+ctrl.6',
#  'g0136+ctrl.7',
#  'g0136+ctrl.8',
#  'g0136+ctrl.9',
#  'g0139+ctrl',
#  'g0139+ctrl.1',
#  'g0139+ctrl.10',
#  'g0139+ctrl.11',
#  'g0139+ctrl.12',
#  'g0139+ctrl.13',
#  'g0139+ctrl.14',
#  'g0139+ctrl.15',
#  'g0139+ctrl.16',
#  'g0139+ctrl.17',
#  'g0139+ctrl.18',
#  'g0139+ctrl.19',
#  'g0139+ctrl.2',
#  'g0139+ctrl.20',
#  'g0139+ctrl.21',
#  'g0139+ctrl.22',
#  'g0139+ctrl.23',
#  'g0139+ctrl.24',
#  'g0139+ctrl.25',
#  'g0139+ctrl.26',
#  'g0139+ctrl.27',
#  'g0139+ctrl.28',
#  'g0139+ctrl.29',
#  'g0139+ctrl.3',
#  'g0139+ctrl.30',
#  'g0139+ctrl.31',
#  'g0139+ctrl.32',
#  'g0139+ctrl.33',
#  'g0139+ctrl.34',
#  'g0139+ctrl.35',
#  'g0139+ctrl.36',
#  'g0139+ctrl.37',
#  'g0139+ctrl.38',
#  'g0139+ctrl.39',
#  'g0139+ctrl.4',
#  'g0139+ctrl.5',
#  'g0139+ctrl.6',
#  'g0139+ctrl.7',
#  'g0139+ctrl.8',
#  'g0139+ctrl.9',
#  'g0147+ctrl',
#  'g0147+ctrl.1',
#  'g0147+ctrl.10',
#  'g0147+ctrl.11',
#  'g0147+ctrl.12',
#  'g0147+ctrl.13',
#  'g0147+ctrl.14',
#  'g0147+ctrl.15',
#  'g0147+ctrl.16',
#  'g0147+ctrl.17',
#  'g0147+ctrl.18',
#  'g0147+ctrl.19',
#  'g0147+ctrl.2',
#  'g0147+ctrl.20',
#  'g0147+ctrl.21',
#  'g0147+ctrl.22',
#  'g0147+ctrl.23',
#  'g0147+ctrl.24',
#  'g0147+ctrl.25',
#  'g0147+ctrl.26',
#  'g0147+ctrl.27',
#  'g0147+ctrl.28',
#  'g0147+ctrl.29',
#  'g0147+ctrl.3',
#  'g0147+ctrl.30',
#  'g0147+ctrl.31',
#  'g0147+ctrl.32',
#  'g0147+ctrl.33',
#  'g0147+ctrl.34',
#  'g0147+ctrl.35',
#  'g0147+ctrl.36',
#  'g0147+ctrl.37',
#  'g0147+ctrl.38',
#  'g0147+ctrl.39',
#  'g0147+ctrl.4',
#  'g0147+ctrl.5',
#  'g0147+ctrl.6',
#  'g0147+ctrl.7',
#  'g0147+ctrl.8',
#  'g0147+ctrl.9',
#  'g0157+ctrl',
#  'g0157+ctrl.1',
#  'g0157+ctrl.10',
#  'g0157+ctrl.11',
#  'g0157+ctrl.12',
#  'g0157+ctrl.13',
#  'g0157+ctrl.14',
#  'g0157+ctrl.15',
#  'g0157+ctrl.16',
#  'g0157+ctrl.17',
#  'g0157+ctrl.18',
#  'g0157+ctrl.19',
#  'g0157+ctrl.2',
#  'g0157+ctrl.20',
#  'g0157+ctrl.21',
#  'g0157+ctrl.22',
#  'g0157+ctrl.23',
#  'g0157+ctrl.24',
#  'g0157+ctrl.25',
#  'g0157+ctrl.26',
#  'g0157+ctrl.27',
#  'g0157+ctrl.28',
#  'g0157+ctrl.29',
#  'g0157+ctrl.3',
#  'g0157+ctrl.30',
#  'g0157+ctrl.31',
#  'g0157+ctrl.32',
#  'g0157+ctrl.33',
#  'g0157+ctrl.34',
#  'g0157+ctrl.35',
#  'g0157+ctrl.36',
#  'g0157+ctrl.37',
#  'g0157+ctrl.38',
#  'g0157+ctrl.39',
#  'g0157+ctrl.4',
#  'g0157+ctrl.5',
#  'g0157+ctrl.6',
#  'g0157+ctrl.7',
#  'g0157+ctrl.8',
#  'g0157+ctrl.9',
#  'g0160+ctrl',
#  'g0160+ctrl.1',
#  'g0160+ctrl.10',
#  'g0160+ctrl.11',
#  'g0160+ctrl.12',
#  'g0160+ctrl.13',
#  'g0160+ctrl.14',
#  'g0160+ctrl.15',
#  'g0160+ctrl.16',
#  'g0160+ctrl.17',
#  'g0160+ctrl.18',
#  'g0160+ctrl.19',
#  'g0160+ctrl.2',
#  'g0160+ctrl.20',
#  'g0160+ctrl.21',
#  'g0160+ctrl.22',
#  'g0160+ctrl.23',
#  'g0160+ctrl.24',
#  'g0160+ctrl.25',
#  'g0160+ctrl.26',
#  'g0160+ctrl.27',
#  'g0160+ctrl.28',
#  'g0160+ctrl.29',
#  'g0160+ctrl.3',
#  'g0160+ctrl.30',
#  'g0160+ctrl.31',
#  'g0160+ctrl.32',
#  'g0160+ctrl.33',
#  'g0160+ctrl.34',
#  'g0160+ctrl.35',
#  'g0160+ctrl.36',
#  'g0160+ctrl.37',
#  'g0160+ctrl.38',
#  'g0160+ctrl.39',
#  'g0160+ctrl.4',
#  'g0160+ctrl.5',
#  'g0160+ctrl.6',
#  'g0160+ctrl.7',
#  'g0160+ctrl.8',
#  'g0160+ctrl.9',
#  'g0186+ctrl',
#  'g0186+ctrl.1',
#  'g0186+ctrl.10',
#  'g0186+ctrl.11',
#  'g0186+ctrl.12',
#  'g0186+ctrl.13',
#  'g0186+ctrl.14',
#  'g0186+ctrl.15',
#  'g0186+ctrl.16',
#  'g0186+ctrl.17',
#  'g0186+ctrl.18',
#  'g0186+ctrl.19',
#  'g0186+ctrl.2',
#  'g0186+ctrl.20',
#  'g0186+ctrl.21',
#  'g0186+ctrl.22',
#  'g0186+ctrl.23',
#  'g0186+ctrl.24',
#  'g0186+ctrl.25',
#  'g0186+ctrl.26',
#  'g0186+ctrl.27',
#  'g0186+ctrl.28',
#  'g0186+ctrl.29',
#  'g0186+ctrl.3',
#  'g0186+ctrl.30',
#  'g0186+ctrl.31',
#  'g0186+ctrl.32',
#  'g0186+ctrl.33',
#  'g0186+ctrl.34',
#  'g0186+ctrl.35',
#  'g0186+ctrl.36',
#  'g0186+ctrl.37',
#  'g0186+ctrl.38',
#  'g0186+ctrl.39',
#  'g0186+ctrl.4',
#  'g0186+ctrl.5',
#  'g0186+ctrl.6',
#  'g0186+ctrl.7',
#  'g0186+ctrl.8',
#  'g0186+ctrl.9',
#  'g0195+ctrl',
#  'g0195+ctrl.1',
#  'g0195+ctrl.10',
#  'g0195+ctrl.11',
#  'g0195+ctrl.12',
#  'g0195+ctrl.13',
#  'g0195+ctrl.14',
#  'g0195+ctrl.15',
#  'g0195+ctrl.16',
#  'g0195+ctrl.17',
#  'g0195+ctrl.18',
#  'g0195+ctrl.19',
#  'g0195+ctrl.2',
#  'g0195+ctrl.20',
#  'g0195+ctrl.21',
#  'g0195+ctrl.22',
#  'g0195+ctrl.23',
#  'g0195+ctrl.24',
#  'g0195+ctrl.25',
#  'g0195+ctrl.26',
#  'g0195+ctrl.27',
#  'g0195+ctrl.28',
#  'g0195+ctrl.29',
#  'g0195+ctrl.3',
#  'g0195+ctrl.30',
#  'g0195+ctrl.31',
#  'g0195+ctrl.32',
#  'g0195+ctrl.33',
#  'g0195+ctrl.34',
#  'g0195+ctrl.35',
#  'g0195+ctrl.36',
#  'g0195+ctrl.37',
#  'g0195+ctrl.38',
#  'g0195+ctrl.39',
#  'g0195+ctrl.4',
#  'g0195+ctrl.5',
#  'g0195+ctrl.6',
#  'g0195+ctrl.7',
#  'g0195+ctrl.8',
#  'g0195+ctrl.9',
#  ...]

# %%
controls = [x for x in cols if (('ctrl' in x) & ('+' not in x))]
controls_df = df[controls]
controls_df
# Out:
#            ctrl    ctrl.1    ctrl.2    ctrl.3    ctrl.4    ctrl.5    ctrl.6  \
# g0001  0.836312  0.028914  0.000000  1.143639  0.017690  0.753267  0.621105
# g0002  0.511849  0.000000  0.021841  0.005361  0.000000  0.000000  1.039343
# g0003  1.445944  2.079188  1.822911  0.012007  1.845350  1.717792  1.531284
# g0004  0.008603  0.000000  0.007871  0.000000  0.663040  0.761658  1.309351
# g0005  1.281513  1.501341  0.457483  0.000000  1.353445  0.000000  1.305790
# ...         ...       ...       ...       ...       ...       ...       ...
# g0996  0.018538  0.017372  0.013594  0.009003  0.018923  0.000000  0.000000
# g0997  0.000000  0.000508  0.000000  0.000000  0.000000  0.000000  0.000000
# g0998  0.003903  0.626856  0.459044  1.663666  0.000000  0.000842  1.018301
# g0999  0.495759  1.003602  1.004071  0.002175  0.384393  0.738528  0.650028
# g1000  1.587759  1.276748  1.720326  0.005455  1.586251  1.469031  1.027721
#
#          ctrl.7    ctrl.8    ctrl.9  ...   ctrl.30   ctrl.31   ctrl.32  \
# g0001  0.995904  0.444173  0.000000  ...  0.000000  0.021107  0.000000
# g0002  0.011422  0.008642  0.001953  ...  0.009748  0.709725  0.000000
# g0003  2.137802  1.338088  2.104632  ...  1.252130  1.258434  1.486947
# g0004  0.968819  0.456875  0.476410  ...  0.474979  0.408065  0.000000
# g0005  1.254025  1.314771  1.045982  ...  0.487891  1.100946  0.000000
# ...         ...       ...       ...  ...       ...       ...       ...
# g0996  0.013630  0.009968  0.000242  ...  0.009389  0.016470  0.000000
# g0997  0.021748  0.000000  0.000000  ...  0.000000  0.412149  0.000000
# g0998  0.616122  0.446489  0.476186  ...  1.068554  0.693600  0.627586
# g0999  0.007703  0.984047  0.789448  ...  0.487926  0.682713  1.278457
# g1000  0.964050  1.465917  1.044782  ...  0.807803  1.503645  1.668902
#
#         ctrl.33   ctrl.34   ctrl.35   ctrl.36   ctrl.37   ctrl.38   ctrl.39
# g0001  0.005619  0.540809  0.516010  0.000000  0.477841  0.008036  0.000480
# g0002  0.000000  0.545621  0.000000  0.557010  0.000000  0.000000  0.005811
# g0003  1.863053  1.690039  1.522627  1.795411  1.429553  1.666555  1.782848
# g0004  0.000000  0.000000  0.881550  1.144585  1.074318  0.807167  0.476822
# g0005  1.310409  0.897603  1.488739  1.363504  1.682196  1.053755  0.791593
# ...         ...       ...       ...       ...       ...       ...       ...
# g0996  0.010173  0.533368  0.009927  0.000000  0.002585  0.796480  0.014837
# g0997  0.019934  0.540004  0.004373  0.000000  0.514076  0.496634  0.463396
# g0998  0.508985  0.007223  0.532241  0.552268  0.006807  1.018918  1.239211
# g0999  0.866744  0.541227  0.009994  0.902098  0.006311  1.023055  0.798029
# g1000  1.326563  1.154830  1.648814  1.363355  1.556474  1.231126  1.546333
#
# [1000 rows x 40 columns]

# %%
fig, ax = plt.subplots()
for i in range(5):
    row = idxs[i]
    ax.hist(controls_df.loc[row], bins=100, density=True, histtype='step', label=row)
    ax.legend();

# %%
c13 = [x for x in cols if 'g0013+ctrl' in x]

# %%
pmask = ['.' in col for col in cols]
copies = cols[pmask]
copies
# Out:
# Index(['g0232+ctrl.1', 'g0852+ctrl.1', 'g0160+g0495.1', 'g0534+g0612.1',
#        'g0301+ctrl.1', 'g0013+ctrl.1', 'g0927+g0805.1', 'g0852+ctrl.2',
#        'g0200+g0605.1', 'g0844+ctrl.1',
#        ...
#        'g0261+g0013.39', 'g0186+g0868.39', 'g0228+g0780.39', 'g0186+g0216.39',
#        'g0520+ctrl.39', 'g0927+g0852.39', 'g0671+ctrl.39', 'g0301+g0139.39',
#        'g0843+ctrl.39', 'g0061+ctrl.39'],
#       dtype='object', length=6903)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: [g0083+g0605, g0095+g0257, g0095+g0520, g0109+g0317, g0109+g0965, g0136+g0965, g0160+g0301, g0160+g0751, g0186+g0241, g0186+g0697, g0186+g0784, g0186+g0787, g0228+g0805, g0261+g0241, g0261+g0276, g0261+g0301, g0301+g0852, g0317+g0965, g0404+g0228, g0404+g0301, g0404+g0422, g0404+g0631, g0422+g0744, g0466+g0605, g0466+g0965, g0495+g0062, g0495+g0228, g0495+g0827, g0534+g0013, g0534+g0139, g0534+g0301, g0534+g0422, g0681+g0062, g0681+g0261, g0681+g0422, g0697+g0760, g0761+g0371, g0780+g0495, g0780+g0827, g0805+g0261, g0805+g0495, g0805+g0599, g0805+g0827, g0924+g0301, g0924+g0852, g0927+g0186, g0957+g0186, g0957+g0261, g0965+g0417]
